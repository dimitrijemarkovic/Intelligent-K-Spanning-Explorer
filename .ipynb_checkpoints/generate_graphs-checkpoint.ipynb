# %%
import networkx as nx
import pickle
import os
import random

def generisi_i_sacuvaj_grafove(broj_grafova=50, min_cvorova=75, max_cvorova=125, direktorijum='grafovi'):
    os.makedirs(direktorijum, exist_ok=True)

    for i in range(broj_grafova):

        broj_cvorova = random.randint(min_cvorova, max_cvorova)

        G = nx.gnp_random_graph(broj_cvorova, 0.3, directed=False)

        ime_fajla = os.path.join(direktorijum, f'graf_{i}.pkl')
        with open(ime_fajla, 'wb') as file:
            pickle.dump(G, file)

# %%
def ucitaj_i_ispisi_grafove(direktorijum='grafovi'):
    ucitani_grafovi = []

    for ime_fajla in os.listdir(direktorijum):
        if ime_fajla.endswith(".pkl"):
            putanja = os.path.join(direktorijum, ime_fajla)
            with open(putanja, 'rb') as file:
                ucitani_graf = pickle.load(file)
                ucitani_grafovi.append(ucitani_graf)

                print(f"Informacije o grafu {ime_fajla}:")
                print(f"  Broj čvorova: {len(ucitani_graf.nodes)}")
                print(f"  Broj grana: {len(ucitani_graf.edges)}")

    return ucitani_grafovi

generisi_i_sacuvaj_grafove()
ucitani_grafovi = ucitaj_i_ispisi_grafove()
# Out:
# Informacije o grafu graf_12.pkl:
#   Broj čvorova: 79
#   Broj grana: 317
# Informacije o grafu graf_32.pkl:
#   Broj čvorova: 106
#   Broj grana: 560
# Informacije o grafu graf_46.pkl:
#   Broj čvorova: 75
#   Broj grana: 264
# Informacije o grafu graf_43.pkl:
#   Broj čvorova: 91
#   Broj grana: 433
# Informacije o grafu graf_38.pkl:
#   Broj čvorova: 120
#   Broj grana: 672
# Informacije o grafu graf_35.pkl:
#   Broj čvorova: 92
#   Broj grana: 440
# Informacije o grafu graf_37.pkl:
#   Broj čvorova: 82
#   Broj grana: 317
# Informacije o grafu graf_7.pkl:
#   Broj čvorova: 97
#   Broj grana: 495
# Informacije o grafu graf_48.pkl:
#   Broj čvorova: 110
#   Broj grana: 603
# Informacije o grafu graf_24.pkl:
#   Broj čvorova: 125
#   Broj grana: 781
# Informacije o grafu graf_14.pkl:
#   Broj čvorova: 115
#   Broj grana: 644
# Informacije o grafu graf_31.pkl:
#   Broj čvorova: 98
#   Broj grana: 501
# Informacije o grafu graf_49.pkl:
#   Broj čvorova: 83
#   Broj grana: 325
# Informacije o grafu graf_3.pkl:
#   Broj čvorova: 86
#   Broj grana: 360
# Informacije o grafu graf_42.pkl:
#   Broj čvorova: 108
#   Broj grana: 571
# Informacije o grafu graf_0.pkl:
#   Broj čvorova: 87
#   Broj grana: 372
# Informacije o grafu graf_15.pkl:
#   Broj čvorova: 116
#   Broj grana: 622
# Informacije o grafu graf_10.pkl:
#   Broj čvorova: 94
#   Broj grana: 442
# Informacije o grafu graf_34.pkl:
#   Broj čvorova: 89
#   Broj grana: 370
# Informacije o grafu graf_19.pkl:
#   Broj čvorova: 119
#   Broj grana: 728
# Informacije o grafu graf_16.pkl:
#   Broj čvorova: 84
#   Broj grana: 339
# Informacije o grafu graf_6.pkl:
#   Broj čvorova: 82
#   Broj grana: 352
# Informacije o grafu graf_28.pkl:
#   Broj čvorova: 81
#   Broj grana: 323
# Informacije o grafu graf_11.pkl:
#   Broj čvorova: 112
#   Broj grana: 619
# Informacije o grafu graf_2.pkl:
#   Broj čvorova: 108
#   Broj grana: 561
# Informacije o grafu graf_39.pkl:
#   Broj čvorova: 98
#   Broj grana: 475
# Informacije o grafu graf_22.pkl:
#   Broj čvorova: 92
#   Broj grana: 412
# Informacije o grafu graf_8.pkl:
#   Broj čvorova: 84
#   Broj grana: 380
# Informacije o grafu graf_13.pkl:
#   Broj čvorova: 111
#   Broj grana: 633
# Informacije o grafu graf_29.pkl:
#   Broj čvorova: 97
#   Broj grana: 497
# Informacije o grafu graf_26.pkl:
#   Broj čvorova: 80
#   Broj grana: 337
# Informacije o grafu graf_40.pkl:
#   Broj čvorova: 120
#   Broj grana: 684
# Informacije o grafu graf_5.pkl:
#   Broj čvorova: 119
#   Broj grana: 664
# Informacije o grafu graf_18.pkl:
#   Broj čvorova: 124
#   Broj grana: 746
# Informacije o grafu graf_33.pkl:
#   Broj čvorova: 107
#   Broj grana: 577
# Informacije o grafu graf_36.pkl:
#   Broj čvorova: 91
#   Broj grana: 410
# Informacije o grafu graf_17.pkl:
#   Broj čvorova: 109
#   Broj grana: 615
# Informacije o grafu graf_30.pkl:
#   Broj čvorova: 113
#   Broj grana: 621
# Informacije o grafu graf_27.pkl:
#   Broj čvorova: 118
#   Broj grana: 670
# Informacije o grafu graf_20.pkl:
#   Broj čvorova: 107
#   Broj grana: 561
# Informacije o grafu graf_47.pkl:
#   Broj čvorova: 115
#   Broj grana: 631
# Informacije o grafu graf_41.pkl:
#   Broj čvorova: 94
#   Broj grana: 449
# Informacije o grafu graf_25.pkl:
#   Broj čvorova: 93
#   Broj grana: 432
# Informacije o grafu graf_44.pkl:
#   Broj čvorova: 100
#   Broj grana: 518
# Informacije o grafu graf_9.pkl:
#   Broj čvorova: 120
#   Broj grana: 693
# Informacije o grafu graf_23.pkl:
#   Broj čvorova: 87
#   Broj grana: 346
# Informacije o grafu graf_21.pkl:
#   Broj čvorova: 116
#   Broj grana: 657
# Informacije o grafu graf_45.pkl:
#   Broj čvorova: 86
#   Broj grana: 349
# Informacije o grafu graf_1.pkl:
#   Broj čvorova: 113
#   Broj grana: 681
# Informacije o grafu graf_4.pkl:
#   Broj čvorova: 89
#   Broj grana: 423
