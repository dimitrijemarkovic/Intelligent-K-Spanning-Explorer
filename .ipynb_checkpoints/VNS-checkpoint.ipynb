# %%
import os
import random
import pickle
import networkx as nx
import math

# %%
def load_random_graph(graphs_folder):
    graph_files = [f for f in os.listdir(graphs_folder) if f.endswith('.pkl')]
    random_graph_file = random.choice(graph_files)
    with open(os.path.join(graphs_folder, random_graph_file), 'rb') as f:
        G = pickle.load(f)
    return G, random_graph_file

# Putanja do foldera sa grafovima
graphs_folder = 'grafovi'

# Učitavanje grafa
G_global, graph_file_name = load_random_graph(graphs_folder)
# G_info = nx.info(G)
num_nodes = G_global.number_of_nodes()

# G_info, num_nodes, graph_file_name
num_nodes, graph_file_name
# Out:
# (99, 'graf_36.pkl')

# %%
def solution_quality(solution):
    return len(solution.nodes())

# %%
def initialize_solution(G, k):
    while True:
        potential_solution = G.copy()
        nodes_to_remove = random.sample(potential_solution.nodes(), k)
        potential_solution.remove_nodes_from(nodes_to_remove)
        if is_k_connected(potential_solution, k):
            return potential_solution

# %%
def local_search(G, k, current_solution):
    # Ova funkcija treba da smanji broj čvorova u rešenju, ako je to moguće
    # Proverava da li može da ukloni bilo koji čvor a da i dalje ostane k-vezan
    print(f'local_search: Broj cvorova na ulasku u local_search {current_solution.number_of_nodes()}')
    temp_solution = current_solution.copy()
    nodes = list(current_solution.nodes())
    random.shuffle(nodes)
    
    for node in nodes:
        temp_solution.remove_node(node)
        
        if not is_k_connected(temp_solution, k):
            temp_solution.add_node(node)

    temp_solution = G.subgraph(temp_solution.nodes())
    
    print(f'local_search: Broj cvorova na izlasku iz local_search {temp_solution.number_of_nodes()} Broj grana na podgrafa {temp_solution.number_of_edges()}')

    return temp_solution

# %%
def is_k_connected(G, k):
    if G.number_of_nodes() < k:
        return False
    else:
        return nx.node_connectivity(G) >= k

# %%
def shaking(G, k, current_solution):
    # Dodavanje ili uklanjanje čvorova ili ivica
    modified_solution = current_solution.copy()

    potential_nodes_to_remove = list(modified_solution.nodes())
    weights_to_remove = [G.degree(node) for node in potential_nodes_to_remove]
    nodes_to_remove = random.choices(potential_nodes_to_remove, weights=weights_to_remove, k=min(max(k, math.floor(len(potential_nodes_to_remove)/(2*k))), len(potential_nodes_to_remove)))
    
    potential_nodes_to_add = list(set(G.nodes()) - set(modified_solution.nodes()))
    weights_to_add = [G.degree(node) for node in potential_nodes_to_add]

    modified_solution.remove_nodes_from(nodes_to_remove)

    if potential_nodes_to_add:

        nodes_to_add = random.choices(potential_nodes_to_add, weights=weights_to_add, k=math.floor(len(potential_nodes_to_add)/2))
        modified_solution.add_nodes_from(nodes_to_add)
            
        for node in nodes_to_add:
            for neighbor in G.neighbors(node):
                if neighbor in modified_solution.nodes():
                     modified_solution.add_edge(node, neighbor)

    
    # if random.choice([True, False]):
    #     # Ukloni slučajno odabrane čvorove, ali ne manje od k
    #     nodes_to_remove = random.sample(modified_solution.nodes(), k)
    #     modified_solution.remove_nodes_from(nodes_to_remove)
    # else:
    #     # Dodaj slučajno odabrane čvorove iz originalnog grafa
    #     potential_nodes = list(set(G.nodes()) - set(modified_solution.nodes()))
    #     nodes_to_add = random.sample(potential_nodes, math.floor(len(potential_nodes)/2))
    #     modified_solution.add_nodes_from(nodes_to_add)
    #     # Dodaj i odgovarajuće ivice
    #     for node in nodes_to_add:
    #         for neighbor in G.neighbors(node):
    #             if neighbor in modified_solution:
    #                 modified_solution.add_edge(node, neighbor)
    
    # Provera da li je i dalje k-vezan
    print(f'shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: {modified_solution.number_of_nodes()}')
    modified_solution = remove_nodes_with_less_than_k_neighbors_optimized(modified_solution, k)
    print(f'shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: {modified_solution.number_of_nodes()}')
    if is_k_connected(modified_solution, k):
        print("shaking: modifikovano resenje je prihvaljivo")
        return modified_solution
    else:
        print("shaking: modifikovano resenje nije prihvaljivo")
        return current_solution

# %%
def remove_nodes_with_less_than_k_neighbors(G, k):
    changed = True
    while changed:
        changed = False
        nodes_to_remove = [node for node in G.nodes if G.degree(node) < k]
        if nodes_to_remove:
            G.remove_nodes_from(nodes_to_remove)
            changed = True
    return G

# %%
from time import perf_counter
import matplotlib.pyplot as plt

# %%
def vns_algorithm(G, k, max_iter=5):
    # Inicijalizacija
    # current_solution = initialize_solution(G, k)
    # print(current_solution.number_of_nodes())
    start_time = perf_counter()
    G = remove_nodes_with_less_than_k_neighbors(G, k)
    best_solution = G.copy()
    print(f'vns_algorithm: broj cvorova na pocetku: {G.number_of_nodes()}')
    while perf_counter() - start_time < 2*60:
        # Shaking
        shaken_solution = shaking(G, k, best_solution)
        # Local search
        new_solution = local_search(G, k, shaken_solution)
        
        # Ažuriranje trenutnog rešenja ako je novo rešenje bolje
        if solution_quality(new_solution) < solution_quality(best_solution):
            best_solution = new_solution.copy()
            print(f'vns_algorithm: nadjeno je novo najbolje resenje: Nodes: {best_solution.number_of_nodes()} Edges:  {best_solution.number_of_edges()}')
    
    return best_solution

# %%
final_solution = vns_algorithm(G_global, 5, 10)
print("Broj cvorova poslednjeg grafa")
print(final_solution.number_of_nodes())
# Out:
# vns_algorithm: broj cvorova na pocetku: 99
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 99
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 99
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 99
# local_search: Broj cvorova na izlasku iz local_search 34 Broj grana na podgrafa 151
# vns_algorithm: nadjeno je novo najbolje resenje: Nodes: 34 Edges:  151
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 29
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 25
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 25
# local_search: Broj cvorova na izlasku iz local_search 25 Broj grana na podgrafa 94
# vns_algorithm: nadjeno je novo najbolje resenje: Nodes: 25 Edges:  94
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 20
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 25
# local_search: Broj cvorova na izlasku iz local_search 22 Broj grana na podgrafa 73
# vns_algorithm: nadjeno je novo najbolje resenje: Nodes: 22 Edges:  73
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 42 Broj grana na podgrafa 247
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 17
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 22
# local_search: Broj cvorova na izlasku iz local_search 22 Broj grana na podgrafa 73
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 35 Broj grana na podgrafa 188
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 28 Broj grana na podgrafa 115
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 32 Broj grana na podgrafa 140
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 35 Broj grana na podgrafa 171
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 17
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 22
# local_search: Broj cvorova na izlasku iz local_search 22 Broj grana na podgrafa 73
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 17
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 22
# local_search: Broj cvorova na izlasku iz local_search 22 Broj grana na podgrafa 73
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 17
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 22
# local_search: Broj cvorova na izlasku iz local_search 22 Broj grana na podgrafa 73
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 17
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 22
# local_search: Broj cvorova na izlasku iz local_search 22 Broj grana na podgrafa 73
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 17
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 22
# local_search: Broj cvorova na izlasku iz local_search 22 Broj grana na podgrafa 73
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 17
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 22
# local_search: Broj cvorova na izlasku iz local_search 21 Broj grana na podgrafa 68
# vns_algorithm: nadjeno je novo najbolje resenje: Nodes: 21 Edges:  68
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 16
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 21
# local_search: Broj cvorova na izlasku iz local_search 21 Broj grana na podgrafa 68
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 16
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 21
# local_search: Broj cvorova na izlasku iz local_search 21 Broj grana na podgrafa 68
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 16
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 21
# local_search: Broj cvorova na izlasku iz local_search 21 Broj grana na podgrafa 68
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 29 Broj grana na podgrafa 114
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 16
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 21
# local_search: Broj cvorova na izlasku iz local_search 21 Broj grana na podgrafa 68
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 34 Broj grana na podgrafa 168
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 38 Broj grana na podgrafa 199
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 37 Broj grana na podgrafa 200
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 44 Broj grana na podgrafa 271
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 38 Broj grana na podgrafa 230
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 16
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 21
# local_search: Broj cvorova na izlasku iz local_search 21 Broj grana na podgrafa 68
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 16
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 21
# local_search: Broj cvorova na izlasku iz local_search 21 Broj grana na podgrafa 68
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 16
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 21
# local_search: Broj cvorova na izlasku iz local_search 21 Broj grana na podgrafa 68
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 16
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 21
# local_search: Broj cvorova na izlasku iz local_search 21 Broj grana na podgrafa 68
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 16
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 21
# local_search: Broj cvorova na izlasku iz local_search 21 Broj grana na podgrafa 68
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 31 Broj grana na podgrafa 155
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 39 Broj grana na podgrafa 224
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 16
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 21
# local_search: Broj cvorova na izlasku iz local_search 21 Broj grana na podgrafa 68
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 60
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 60
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 60
# local_search: Broj cvorova na izlasku iz local_search 28 Broj grana na podgrafa 116
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 16
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 0
# shaking: modifikovano resenje nije prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 21
# local_search: Broj cvorova na izlasku iz local_search 20 Broj grana na podgrafa 63
# vns_algorithm: nadjeno je novo najbolje resenje: Nodes: 20 Edges:  63
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 59
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 59
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 59
# local_search: Broj cvorova na izlasku iz local_search 35 Broj grana na podgrafa 173
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 59
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 59
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 59
# local_search: Broj cvorova na izlasku iz local_search 40 Broj grana na podgrafa 210
# shaking: broj cvorova pre pomeranja cvorova sa manje od k suseda: 59
# shaking: broj cvorova posle pomeranja cvorova sa manje od k suseda: 59
# shaking: modifikovano resenje je prihvaljivo
# local_search: Broj cvorova na ulasku u local_search 59
# local_search: Broj cvorova na izlasku iz local_search 40 Broj grana na podgrafa 229
# Broj cvorova poslednjeg grafa
# 20

# %%
nx.draw(final_solution,with_labels=True, font_weight='bold')
plt.show()

# %%
from itertools import combinations

def brute_force_algorithm(G, k):
    all_nodes = list(G.nodes())
    n = len(all_nodes)

    # Provera svih mogućih kombinacija čvorova od najmanjeg broja čvorova ka većima
    for r in range(k, n+1):
        for nodes in combinations(all_nodes, r):
            subgraph = G.subgraph(nodes)
            if is_k_connected(subgraph, k):
                return subgraph  # Vraća prvi graf koji zadovoljava uslov

    return None

# %%
optimal_solution = brute_force_algorithm(final_solution, 5)
print(f'brute_force_algorithm: Nodes: {optimal_solution.number_of_nodes()} Edges:  {optimal_solution.number_of_edges()}')
nx.draw(optimal_solution, with_labels=True, font_weight='bold')
plt.show()
# Out:
# brute_force_algorithm: Nodes: 15 Edges:  42
